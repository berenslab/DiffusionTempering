# %%
using DrWatson
@quickactivate "FenrirForNeuro"
using CairoMakie
using CSV, DataFrames
using Printf
using PrettyTables
using Statistics, LinearAlgebra
using FenrirForNeuro, ModelingToolkit, OrdinaryDiffEq
using FileIO
using StatsBase

Axis = CairoMakie.Axis
# Out:
# Makie.Axis

# %%
# helpers
function import_csvs(fpaths, header=nothing)
    dfs = []
    for fpath in fpaths
        df = CSV.read(fpath, DataFrame, header=false)
        if header != nothing
            rename!(df, header)
        end
        df[!, :iter] = 1:size(df, 1)
        push!(dfs, df)
    end
    return dfs
end

get_last_rows(trajectories) = vcat([DataFrame(t[end, :]) for t in trajectories]...)


function where_converged(trajectories, threshold=5e-2)
    last_rows = get_last_rows(trajectories)
    pRMSEs = map(x -> rel_pRMSE(x, pvalues(θ)), eachrow(Array(last_rows[!, pkeys(θ)])))
    return pRMSEs .< 5e-2
end


l2 = get_l2_loss()

pkeys(θ) = map(θᵢ -> Symbol(θᵢ[1]), θ)
pvalues(θ) = map(θᵢ -> θᵢ[2], θ)
# Out:
# pvalues (generic function with 1 method)

# %%
HALF_WIDTH = ((6.75 - 0.25) / 2) # inches
FULL_WIDTH = 6.75 # inches
HEIGHT = 0.7 * 3.25 # inches

PT_PER_INCH = 72
HALF_WIDTH *= PT_PER_INCH
FULL_WIDTH *= PT_PER_INCH
HEIGHT *= PT_PER_INCH

RESULTS_PATH = "../../results/"
FIGURES_PATH = "../../figures/"

PLOT_DEFAULTS = (titlesize=7, xlabelsize=7, ylabelsize=7, xticklabelsize=7, yticklabelsize=7, xticksize=2, yticksize=2)
# Out:
# (titlesize = 7, xlabelsize = 7, ylabelsize = 7, xticklabelsize = 7, yticklabelsize = 7, xticksize = 2, yticksize = 2)

# %%
@parameters gNa gK 
θ = [gNa => 25, gK => 7]
prob_prior, prob = get_SinglecompartmentHH(θ)

proj = [1 0 0 0]
# observation = generate_data(prob, proj, 1e-2, 1e-2)
# Out:
# 1×4 Matrix{Int64}:
#  1  0  0  0

# %%
IN_PATH = RESULTS_PATH * "hh/2p/simple/fenrir/tempering_tradeoff"
FNAMES = readdir(IN_PATH)
FPATHS = [joinpath(IN_PATH, fname) for fname in FNAMES]
κ²0 = 20.0
T10(t::Real)::Float64 = 10.0^(κ²0 - t)
tempering_schedules = [T10.(LinRange(0, 20, n_steps)) for n_steps in 5:21]

IN_PATH = RESULTS_PATH * "hh/2p/simple/fenrir/exp_tempered_diff"
FNAMES = readdir(IN_PATH)
exp_fpaths = [joinpath(IN_PATH, fname) for fname in FNAMES]
κ²0 = 20.0
τ = 5.0;
T(t::Real)::Float64 = 10.0^(κ²0 * exp(-t / τ));
exp_tempering_schedule = T.(LinRange(0, 20, 21))
push!(tempering_schedules, exp_tempering_schedule)
last_rows_by_schedule = []
for (i, schedule) in enumerate(tempering_schedules)
    fpaths = i < length(tempering_schedules) ? filter(x -> occursin("-$i-", x), FPATHS) : exp_fpaths
    trajectories = import_csvs(fpaths, [pkeys(θ)..., :κ², :l, :T])
    last_rows_at_κ² = []
    last(x) = x[end, :]
    push!(last_rows_by_schedule, [combine(groupby(t, :κ²), last) for t in trajectories])
end
only_last_rows_by_schedule = [vcat([DataFrame(l[argmin(l[!, :κ²]), :]) for l in last_rows]...) for last_rows in last_rows_by_schedule]
# Out:
# 18-element Vector{DataFrame}:
#  97×6 DataFrame
#  Row │ κ²       gNa      gK        l             T        iter
#      │ Float64  Float64  Float64   Float64       Float64  Int64
# ─────┼──────────────────────────────────────────────────────────
#    1 │     1.0   0.5     15.0         1.38266e7  1813.51    311
#    2 │     1.0  24.9715   6.97769  2780.37       1777.19    280
#    3 │     1.0   0.5     15.0         1.38266e7  1695.61    300
#    4 │     1.0  24.9715   6.97769  2780.37       2498.44    469
#    5 │     1.0  24.9715   6.97769  2780.37       1873.32    307
#    6 │     1.0   0.5     15.0         1.38266e7  1447.57    253
#    7 │     1.0  24.9715   6.97769  2780.37       1375.66    226
#    8 │     1.0  24.9715   6.97769  2780.37       1597.87    250
#   ⋮  │    ⋮        ⋮        ⋮           ⋮           ⋮       ⋮
#   91 │     1.0  24.9715   6.97769  2780.37       2629.03    235
#   92 │     1.0  24.9715   6.97769  2780.37       2290.66    220
#   93 │     1.0  24.9715   6.97769  2780.37       2956.91    289
#   94 │     1.0  24.9715   6.97769  2780.37       2078.42    166
#   95 │     1.0  24.9715   6.97769  2780.37       2539.68    260
#   96 │     1.0  24.9715   6.97769  2780.37       3117.94    330
#   97 │     1.0  24.9715   6.97769  2780.37       2994.08    321
#                                                  82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l         T        iter
#      │ Float64  Float64  Float64  Float64   Float64  Int64
# ─────┼─────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769   2780.37  2072.77    369
#    2 │     1.0  24.979   6.98167   2866.73  1895.21    322
#    3 │     1.0  24.9715  6.97769   2780.37  2174.28    388
#    4 │     1.0  24.8972  6.97334  17036.9   2681.34    511
#    5 │     1.0  24.979   6.98167   2866.73  2326.35    404
#    6 │     1.0  24.9715  6.97769   2780.37  1569.43    261
#    7 │     1.0  24.9715  6.97769   2780.37  1816.72    308
#    8 │     1.0  24.9715  6.97769   2780.37  1843.69    320
#   ⋮  │    ⋮        ⋮        ⋮        ⋮         ⋮       ⋮
#   91 │     1.0  24.9715  6.97769   2780.37  3477.25    325
#   92 │     1.0  24.9715  6.97769   2780.37  3183.3     335
#   93 │     1.0  24.9715  6.97769   2780.37  3829.27    386
#   94 │     1.0  24.979   6.98167   2866.73  2466.52    236
#   95 │     1.0  24.979   6.98167   2866.73  2855.29    300
#   96 │     1.0  24.9715  6.97769   2780.37  2793.02    311
#   97 │     1.0  24.9715  6.97769   2780.37  3944.25    424
#                                             82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK        l             T        iter
#      │ Float64  Float64  Float64   Float64       Float64  Int64
# ─────┼──────────────────────────────────────────────────────────
#    1 │     1.0   0.5     15.0         1.38266e7  2043.93    405
#    2 │     1.0  24.9715   6.97769  2780.37       2283.17    417
#    3 │     1.0  24.9715   6.97769  2780.37       1985.64    357
#    4 │     1.0  24.9715   6.97769  2780.37       2790.48    526
#    5 │     1.0  24.9715   6.97769  2780.37       1860.46    333
#    6 │     1.0  24.9715   6.97769  2780.37       1845.05    317
#    7 │     1.0  24.9715   6.97769  2780.37       1800.98    292
#    8 │     1.0  24.9715   6.97769  2780.37       2003.26    324
#   ⋮  │    ⋮        ⋮        ⋮           ⋮           ⋮       ⋮
#   91 │     1.0  24.9715   6.97769  2780.37       3128.99    311
#   92 │     1.0  24.9715   6.97769  2780.37       3864.12    406
#   93 │     1.0  24.979    6.98167  2866.73       3500.44    380
#   94 │     1.0  24.9715   6.97769  2780.37       2669.11    285
#   95 │     1.0  24.9715   6.97769  2780.37       3329.74    334
#   96 │     1.0  24.9715   6.97769  2780.37       3339.78    358
#   97 │     1.0  24.9715   6.97769  2780.37       3362.55    374
#                                                  82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK        l             T        iter
#      │ Float64  Float64  Float64   Float64       Float64  Int64
# ─────┼──────────────────────────────────────────────────────────
#    1 │     1.0  24.9715   6.97769  2780.37       2161.67    357
#    2 │     1.0   0.5     15.0         1.38266e7  2383.07    469
#    3 │     1.0   0.5     15.0         1.38266e7  2205.57    448
#    4 │     1.0  24.9715   6.97769  2780.37       2648.37    512
#    5 │     1.0  24.9715   6.97769  2780.37       2104.52    386
#    6 │     1.0  24.9715   6.97769  2780.37       1485.81    250
#    7 │     1.0   0.5     15.0         1.38266e7  2075.49    413
#    8 │     1.0   0.5     15.0         1.38266e7  2249.01    440
#   ⋮  │    ⋮        ⋮        ⋮           ⋮           ⋮       ⋮
#   91 │     1.0   0.5     15.0         1.38266e7  3604.17    421
#   92 │     1.0  24.9715   6.97769  2780.37       3544.44    361
#   93 │     1.0   0.5     15.0         1.38266e7  3541.92    434
#   94 │     1.0  24.9715   6.97769  2780.37       5762.05    646
#   95 │     1.0   0.5     15.0         1.38266e7  3560.71    429
#   96 │     1.0  24.9715   6.97769  2780.37       3544.42    362
#   97 │     1.0   0.5     15.0         1.38266e7  4264.06    530
#                                                  82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK        l             T        iter
#      │ Float64  Float64  Float64   Float64       Float64  Int64
# ─────┼──────────────────────────────────────────────────────────
#    1 │     1.0  24.9715   6.97769  2780.37       2110.94    354
#    2 │     1.0   0.5     15.0         1.38266e7  2311.96    461
#    3 │     1.0   0.5     15.0         1.38266e7  3081.62    563
#    4 │     1.0   0.5     15.0         1.38266e7  3247.29    674
#    5 │     1.0   0.5     15.0         1.38266e7  2531.13    501
#    6 │     1.0  24.9715   6.97769  2780.37       2296.9     391
#    7 │     1.0  24.979    6.98167  2866.73       2069.55    349
#    8 │     1.0  24.9715   6.97769  2780.37       2115.37    344
#   ⋮  │    ⋮        ⋮        ⋮           ⋮           ⋮       ⋮
#   91 │     1.0  24.9715   6.97769  2780.37       3988.48    436
#   92 │     1.0  24.9715   6.97769  2780.37       4439.84    466
#   93 │     1.0   0.5     15.0         1.38266e7  3897.28    489
#   94 │     1.0  24.979    6.98167  2866.73       3121.39    322
#   95 │     1.0   0.5     15.0         1.38266e7  4145.99    490
#   96 │     1.0   0.5     15.0         1.38266e7  4134.3     495
#   97 │     1.0  24.9567   6.96624  3113.99       3953.9     430
#                                                  82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769  2780.37  2174.18    382
#    2 │     1.0  24.9882  6.9782   2803.14  2795.28    497
#    3 │     1.0  24.9715  6.97769  2780.37  3509.75    639
#    4 │     1.0  24.979   6.98167  2866.73  3426.19    621
#    5 │     1.0  24.979   6.98167  2866.73  2013.56    355
#    6 │     1.0  24.979   6.98167  2866.73  2865.54    513
#    7 │     1.0  24.979   6.98167  2866.73  2693.78    472
#    8 │     1.0  24.9559  6.9613   3149.79  2815.95    483
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.979   6.98167  2866.73  3960.12    408
#   92 │     1.0  24.979   6.98167  2866.73  3627.04    386
#   93 │     1.0  24.9715  6.97769  2780.37  5297.02    553
#   94 │     1.0  24.9715  6.97769  2780.37  3764.22    393
#   95 │     1.0  24.979   6.98167  2866.73  3664.08    386
#   96 │     1.0  24.979   6.98167  2866.73  4169.71    453
#   97 │     1.0  24.979   6.98167  2866.73  4279.93    462
#                                            82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.979   6.98167  2866.73  2636.63    443
#    2 │     1.0  24.9715  6.97769  2780.37  2419.94    424
#    3 │     1.0  24.9715  6.97769  2780.37  2282.0     400
#    4 │     1.0  24.979   6.98167  2866.73  3153.69    599
#    5 │     1.0  24.9715  6.97769  2780.37  2381.58    417
#    6 │     1.0  24.9715  6.97769  2780.37  2282.19    392
#    7 │     1.0  24.9715  6.97769  2780.37  2360.85    403
#    8 │     1.0  24.9715  6.97769  2780.37  2621.26    452
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.9715  6.97769  2780.37  4932.82    502
#   92 │     1.0  24.9882  6.9782   2803.14  4122.1     437
#   93 │     1.0  24.9715  6.97769  2780.37  3591.14    371
#   94 │     1.0  24.9715  6.97769  2780.37  4242.13    431
#   95 │     1.0  24.979   6.98167  2866.73  3721.56    391
#   96 │     1.0  24.9715  6.97769  2780.37  4341.6     456
#   97 │     1.0  24.9715  6.97769  2780.37  4644.54    504
#                                            82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T         iter
#      │ Float64  Float64  Float64  Float64  Float64   Int64
# ─────┼─────────────────────────────────────────────────────
#    1 │     1.0  24.9882  6.9782   2803.14   4339.51    788
#    2 │     1.0  24.9715  6.97769  2780.37   4103.05    738
#    3 │     1.0  24.9715  6.97769  2780.37   3012.04    539
#    4 │     1.0  24.9715  6.97769  2780.37   5333.28    995
#    5 │     1.0  24.9715  6.97769  2780.37   3744.18    611
#    6 │     1.0  24.9882  6.9782   2803.14   3647.55    661
#    7 │     1.0  24.9715  6.97769  2780.37   2941.62    494
#    8 │     1.0  24.979   6.98167  2866.73   2553.49    422
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮        ⋮
#   91 │     1.0  24.9715  6.97769  2780.37   5117.59    544
#   92 │     1.0  24.9715  6.97769  2780.37   3934.11    425
#   93 │     1.0  24.979   6.98167  2866.73   4088.43    440
#   94 │     1.0  24.9882  6.9782   2803.14   4219.87    436
#   95 │     1.0  24.9715  6.97769  2780.37   4748.18    477
#   96 │     1.0  24.9882  6.9782   2803.14  16251.2    1921
#   97 │     1.0  24.9715  6.97769  2780.37   4955.25    545
#                                             82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.979   6.98167  2866.73  3045.06    522
#    2 │     1.0  24.9715  6.97769  2780.37  3771.67    666
#    3 │     1.0  24.9715  6.97769  2780.37  3220.52    542
#    4 │     1.0  24.979   6.98167  2866.73  3937.75    709
#    5 │     1.0  24.9715  6.97769  2780.37  2818.79    488
#    6 │     1.0  24.979   6.98167  2866.73  2855.39    494
#    7 │     1.0  24.979   6.98167  2866.73  3356.14    570
#    8 │     1.0  24.979   6.98167  2866.73  3039.36    498
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.9715  6.97769  2780.37  5329.36    514
#   92 │     1.0  24.9715  6.97769  2780.37  6269.78    633
#   93 │     1.0  24.979   6.98167  2866.73  4649.06    477
#   94 │     1.0  24.979   6.98167  2866.73  3693.97    349
#   95 │     1.0  24.9715  6.97769  2780.37  5325.07    546
#   96 │     1.0  24.9715  6.97769  2780.37  4751.19    498
#   97 │     1.0  24.9715  6.97769  2780.37  5190.7     526
#                                            82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK        l             T         iter
#      │ Float64  Float64  Float64   Float64       Float64   Int64
# ─────┼───────────────────────────────────────────────────────────
#    1 │     1.0  24.9715   6.97769  2780.37        3656.54    617
#    2 │     1.0  24.9715   6.97769  2780.37        2727.44    454
#    3 │     1.0  24.9715   6.97769  2780.37        3058.0     535
#    4 │     1.0   0.5     15.0         1.38266e7   4454.01    915
#    5 │     1.0  24.9715   6.97769  2780.37        3610.43    641
#    6 │     1.0  24.9715   6.97769  2780.37        2967.03    504
#    7 │     1.0   0.5     15.0         1.38266e7   3898.77    749
#    8 │     1.0  24.9715   6.97769  2780.37        3284.41    525
#   ⋮  │    ⋮        ⋮        ⋮           ⋮           ⋮        ⋮
#   91 │     1.0   0.5     15.0         1.38266e7   5456.88    673
#   92 │     1.0   0.5     15.0         1.38266e7   5612.35    691
#   93 │     1.0   0.5     15.0         1.38266e7   5572.65    692
#   94 │     1.0  24.9715   6.97769  2780.37        4759.91    475
#   95 │     1.0  24.9715   6.97769  2780.37       18185.4    2008
#   96 │     1.0  24.979    6.98167  2866.73        5055.88    534
#   97 │     1.0  24.979    6.98167  2866.73        5737.97    603
#                                                   82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T         iter
#      │ Float64  Float64  Float64  Float64  Float64   Int64
# ─────┼─────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769  2780.37   3764.99    605
#    2 │     1.0  24.9715  6.97769  2780.37   3696.08    618
#    3 │     1.0  24.979   6.98167  2866.73   3297.96    564
#    4 │     1.0  24.9715  6.97769  2780.37   4622.61    831
#    5 │     1.0  24.9715  6.97769  2780.37   3132.59    538
#    6 │     1.0  24.9715  6.97769  2780.37   3893.78    653
#    7 │     1.0  24.9715  6.97769  2780.37   3171.42    512
#    8 │     1.0  24.979   6.98167  2866.73   4371.71    733
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮        ⋮
#   91 │     1.0  24.979   6.98167  2866.73   6769.37    715
#   92 │     1.0  24.979   6.98167  2866.73   5506.94    583
#   93 │     1.0  24.979   6.98167  2866.73  10338.1    1179
#   94 │     1.0  24.979   6.98167  2866.73   3947.12    410
#   95 │     1.0  24.9715  6.97769  2780.37   5421.08    533
#   96 │     1.0  24.979   6.98167  2866.73   5474.1     574
#   97 │     1.0  24.9715  6.97769  2780.37   5426.87    567
#                                             82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769  2780.37  3474.03    574
#    2 │     1.0  24.9715  6.97769  2780.37  3440.14    604
#    3 │     1.0  24.9715  6.97769  2780.37  3429.86    602
#    4 │     1.0  24.9715  6.97769  2780.37  3943.31    704
#    5 │     1.0  24.9715  6.97769  2780.37  2920.48    494
#    6 │     1.0  24.9715  6.97769  2780.37  2517.52    412
#    7 │     1.0  24.979   6.98167  2866.73  3694.81    621
#    8 │     1.0  24.9715  6.97769  2780.37  3672.32    604
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.9715  6.97769  2780.37  5851.09    572
#   92 │     1.0  24.9715  6.97769  2780.37  4938.94    506
#   93 │     1.0  24.9715  6.97769  2780.37  5623.21    613
#   94 │     1.0  24.9715  6.97769  2780.37  4842.97    465
#   95 │     1.0  24.9715  6.97769  2780.37  6525.69    675
#   96 │     1.0  24.9715  6.97769  2780.37  5471.3     577
#   97 │     1.0  24.9715  6.97769  2780.37  5887.77    612
#                                            82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769  2780.37  3336.6     548
#    2 │     1.0  24.979   6.98167  2866.73  3482.23    589
#    3 │     1.0  24.9715  6.97769  2780.37  3536.11    591
#    4 │     1.0  24.9715  6.97769  2780.37  4498.64    807
#    5 │     1.0  24.9552  6.96558  3040.34  3760.77    636
#    6 │     1.0  24.9715  6.97769  2780.37  3045.16    497
#    7 │     1.0  24.9715  6.97769  2780.37  3394.8     568
#    8 │     1.0  24.9567  6.96624  3113.99  3554.18    614
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.9715  6.97769  2780.37  5627.11    586
#   92 │     1.0  24.9715  6.97769  2780.37  5483.35    581
#   93 │     1.0  24.9715  6.97769  2780.37  5249.88    559
#   94 │     1.0  24.9715  6.97769  2780.37  5691.12    557
#   95 │     1.0  24.9715  6.97769  2780.37  7562.42    823
#   96 │     1.0  24.9715  6.97769  2780.37  5276.76    558
#   97 │     1.0  24.9715  6.97769  2780.37  6481.22    700
#                                            82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769  2780.37  3727.96    617
#    2 │     1.0  24.9715  6.97769  2780.37  3794.94    625
#    3 │     1.0  24.9715  6.97769  2780.37  3931.26    667
#    4 │     1.0  24.979   6.98167  2866.73  4354.82    795
#    5 │     1.0  24.979   6.98167  2866.73  3967.4     677
#    6 │     1.0  24.9715  6.97769  2780.37  4011.26    652
#    7 │     1.0  24.9715  6.97769  2780.37  3861.57    647
#    8 │     1.0  24.9715  6.97769  2780.37  5123.09    884
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.979   6.98167  2866.73  5782.25    604
#   92 │     1.0  24.979   6.98167  2866.73  5789.63    565
#   93 │     1.0  24.9715  6.97769  2780.37  4902.73    523
#   94 │     1.0  24.979   6.98167  2866.73  4963.56    511
#   95 │     1.0  24.9715  6.97769  2780.37  5652.27    592
#   96 │     1.0  24.9715  6.97769  2780.37  6434.26    660
#   97 │     1.0  24.9715  6.97769  2780.37  6141.61    658
#                                            82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.979   6.98167  2866.73  4050.33    647
#    2 │     1.0  24.9882  6.9782   2803.14  3410.77    555
#    3 │     1.0  24.9715  6.97769  2780.37  3795.8     625
#    4 │     1.0  24.9715  6.97769  2780.37  4709.2     840
#    5 │     1.0  24.9715  6.97769  2780.37  5000.3     849
#    6 │     1.0  24.9882  6.9782   2803.14  7275.0    1339
#    7 │     1.0  24.9715  6.97769  2780.37  3623.19    605
#    8 │     1.0  24.9715  6.97769  2780.37  4593.7     755
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.9715  6.97769  2780.37  6595.13    681
#   92 │     1.0  24.9715  6.97769  2780.37  7416.16    720
#   93 │     1.0  24.9882  6.9782   2803.14  6151.16    621
#   94 │     1.0  24.9715  6.97769  2780.37  5160.05    481
#   95 │     1.0  24.9882  6.9782   2803.14  6427.39    651
#   96 │     1.0  24.9882  6.9782   2803.14  6569.8     679
#   97 │     1.0  24.9715  6.97769  2780.37  7147.57    725
#                                            82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T         iter
#      │ Float64  Float64  Float64  Float64  Float64   Int64
# ─────┼─────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769  2780.37   4335.39    696
#    2 │     1.0  24.9715  6.97769  2780.37   3982.34    656
#    3 │     1.0  24.9715  6.97769  2780.37   3819.44    639
#    4 │     1.0  24.9715  6.97769  2780.37   4545.4     809
#    5 │     1.0  24.9715  6.97769  2780.37   4222.12    701
#    6 │     1.0  24.979   6.98167  2866.73   4337.05    730
#    7 │     1.0  24.9715  6.97769  2780.37   4530.0     750
#    8 │     1.0  24.9715  6.97769  2780.37   4609.63    750
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮        ⋮
#   91 │     1.0  24.9715  6.97769  2780.37   6284.88    600
#   92 │     1.0  24.979   6.98167  2866.73   6990.99    706
#   93 │     1.0  24.9715  6.97769  2780.37  12348.0    1402
#   94 │     1.0  24.9715  6.97769  2780.37   5155.64    486
#   95 │     1.0  24.9715  6.97769  2780.37   7372.35    761
#   96 │     1.0  24.9715  6.97769  2780.37   7254.78    718
#   97 │     1.0  24.979   6.98167  2866.73   7597.2     797
#                                             82 rows omitted
#  97×6 DataFrame
#  Row │ κ²       gNa      gK       l        T        iter
#      │ Float64  Float64  Float64  Float64  Float64  Int64
# ─────┼────────────────────────────────────────────────────
#    1 │     1.0  24.9715  6.97769  2780.37  4407.56    732
#    2 │     1.0  24.9715  6.97769  2780.37  3969.42    670
#    3 │     1.0  24.9882  6.9782   2803.14  3569.11    608
#    4 │     1.0  24.9715  6.97769  2780.37  4765.52    830
#    5 │     1.0  24.9715  6.97769  2780.37  4211.85    707
#    6 │     1.0  24.9715  6.97769  2780.37  3861.89    632
#    7 │     1.0  24.9715  6.97769  2780.37  4492.23    740
#    8 │     1.0  24.9715  6.97769  2780.37  4276.74    700
#   ⋮  │    ⋮        ⋮        ⋮        ⋮        ⋮       ⋮
#   91 │     1.0  24.979   6.98167  2866.73  6058.45    622
#   92 │     1.0  24.9715  6.97769  2780.37  5922.98    616
#   93 │     1.0  24.9715  6.97769  2780.37  6326.63    662
#   94 │     1.0  24.9715  6.97769  2780.37  7586.1     800
#   95 │     1.0  24.9715  6.97769  2780.37  6798.31    691
#   96 │     1.0  24.9715  6.97769  2780.37  6206.32    656
#   97 │     1.0  24.9715  6.97769  2780.37  7153.81    744
#                                            82 rows omitted
#  100×6 DataFrame
#  Row │ κ²       gNa      gK        l             T        iter
#      │ Float64  Float64  Float64   Float64       Float64  Int64
# ─────┼──────────────────────────────────────────────────────────
#    1 │ 2.32441  24.9715   6.97769  2780.37       2213.92    398
#    2 │ 2.32441  24.9715   6.97769  2780.37       2750.03    505
#    3 │ 2.32441  24.9882   6.9782   2803.14       2388.93    468
#    4 │ 2.32441  24.9715   6.97769  2780.37       3473.59    744
#    5 │ 2.32441  24.9715   6.97769  2780.37       1978.29    394
#    6 │ 2.32441  24.9715   6.97769  2780.37       2171.43    395
#    7 │ 2.32441  24.9715   6.97769  2780.37       2540.39    472
#    8 │ 2.32441  24.9715   6.97769  2780.37       3199.35    596
#   ⋮  │    ⋮        ⋮        ⋮           ⋮           ⋮       ⋮
#   94 │ 2.32441  24.9715   6.97769  2780.37       2525.73    485
#   95 │ 2.32441  24.9715   6.97769  2780.37       2480.08    506
#   96 │ 2.32441  24.9715   6.97769  2780.37       2817.46    540
#   97 │ 2.32441  24.9882   6.9782   2803.14       2047.64    381
#   98 │ 2.32441   0.5     15.0         1.38266e7  3487.75    892
#   99 │ 2.32441  24.9715   6.97769  2780.37       2535.9     533
#  100 │ 2.32441  24.9715   6.97769  2780.37       2333.43    475
#                                                  85 rows omitted

# %%
metrics = []
metrics_per_κ² = []
for (i, schedule) in enumerate(tempering_schedules)
    only_last_rows = only_last_rows_by_schedule[i]
    all_last_rows = last_rows_by_schedule[i]
    metrics_cache = []
    for (k, rows) in enumerate([only_last_rows, schedule...])
        last_rows = k == 1 ? only_last_rows : vcat([DataFrame(last_row[k-1, :]) for last_row in all_last_rows]...)
        θ_est = Array(last_rows[!, pkeys(θ)])
        pRMSEs = map(x -> rel_pRMSE(x, pvalues(θ)), eachrow(θ_est))
        
        last_rows[!, :pRMSE] = [pRMSEs...]
        last_rows[!, :conv] = [(pRMSEs .< 5e-2)...]
        
        conv = mean(last_rows[!, :conv])
        pRMSE = mean(last_rows[!, :pRMSE])
        num_iter = mean(last_rows[!, :iter])
        push!(k == 1 ? metrics : metrics_cache, [conv, pRMSE, num_iter])
    end
    push!(metrics_per_κ², metrics_cache)
end
metrics = stack(metrics)'
metrics = map(x -> Float64(x), metrics)

metrics_per_κ² = [map(x -> Float64(x), hcat(metrics...)') for metrics in metrics_per_κ²]
# Out:
# 18-element Vector{Matrix{Float64}}:
#  [0.0 0.9637798443147313 115.51546391752578; 0.7628865979381443 0.19036113763393536 198.5979381443299; … ; 0.8041237113402062 0.21056081868159215 270.35051546391753; 0.8041237113402062 0.21039601120359233 287.3917525773196]
#  [0.0 0.9637798443147313 116.54639175257732; 0.8350515463917526 0.13124341827090796 229.1237113402062; … ; 0.9690721649484536 0.03519689126856493 343.1443298969072; 0.9690721649484536 0.03520543414511588 354.36082474226805]
#  [0.0 0.9637798443147313 117.02061855670104; 0.6907216494845361 0.17765909291490403 200.94845360824743; … ; 0.8762886597938144 0.1337596391850068 372.30927835051546; 0.8762886597938144 0.13378743730559325 383.8144329896907]
#  [0.0 0.9637798443147313 117.14432989690722; 0.1958762886597938 0.39889976832417656 184.1958762886598; … ; 0.6907216494845361 0.33102020912172764 386.3298969072165; 0.6907216494845361 0.330951641172267 402.64948453608247]
#  [0.0 0.9637798443147313 117.97938144329896; 0.020618556701030927 0.7308669601256064 193.4742268041237; … ; 0.38144329896907214 0.6545068955434008 441.88659793814435; 0.38144329896907214 0.6545085225502655 465.3917525773196]
#  [0.0 0.9637798443147313 117.37113402061856; 0.010309278350515464 1.0010802557576366 197.2577319587629; … ; 0.979381443298969 0.024194182965130432 442.02061855670104; 0.979381443298969 0.024191752051926023 449.7113402061856]
#  [0.0 0.9637798443147313 118.11340206185567; 0.0 1.0474940609777683 174.4020618556701; … ; 1.0 0.0024536783497750092 467.70103092783506; 1.0 0.002435242210989356 474.78350515463916]
#  [0.0 0.9637798443147313 117.43298969072166; 0.0 1.0442092823763012 177.4536082474227; … ; 0.9896907216494846 0.013243629056125162 541.7319587628866; 0.9896907216494846 0.01324994974321735 548.8041237113403]
#  [0.0 0.9637798443147313 117.9381443298969; 0.0 0.7188668878279182 181.82474226804123; … ; 0.9896907216494846 0.013153381505208492 551.4536082474227; 0.9896907216494846 0.013153381355315255 558.3917525773196]
#  [0.0 0.9637798443147313 120.52577319587628; 0.0 0.7258253331993657 190.17525773195877; … ; 0.711340206185567 0.2895609881151114 615.2061855670103; 0.711340206185567 0.2895702199028022 628.8865979381443]
#  [0.0 0.9637798443147313 118.72164948453609; 0.0 0.8384003558577121 190.84536082474227; … ; 0.979381443298969 0.01931330893104479 629.4742268041238; 0.979381443298969 0.01932083581902208 635.8556701030927]
#  [0.0 0.9637798443147313 118.38144329896907; 0.0 0.8886257328967625 191.08247422680412; … ; 1.0 0.002373625492884566 596.9072164948453; 1.0 0.002379944939985441 603.5360824742268]
#  [0.0 0.9637798443147313 118.94845360824742; 0.0 0.9086988638481505 190.0; … ; 1.0 0.0025572255008197613 617.0515463917526; 1.0 0.0025445324849764964 623.2577319587629]
#  [0.0 0.9637798443147313 119.30927835051547; 0.0 0.9312951576573889 192.51546391752578; … ; 1.0 0.0023005350781535707 659.979381443299; 1.0 0.002302239418940166 666.0412371134021]
#  [0.0 0.9637798443147313 120.47422680412372; 0.0 0.9243743788268618 206.7319587628866; … ; 1.0 0.002352345319554237 712.6288659793814; 1.0 0.0023523452810185444 718.680412371134]
#  [0.0 0.9637798443147313 119.88659793814433; 0.0 0.9340580741700394 191.7422680412371; … ; 1.0 0.0023141173145910608 695.2577319587629; 1.0 0.0023187330009721537 701.6082474226804]
#  [0.0 0.9637798443147313 120.11340206185567; 0.0 0.9411852629699748 196.39175257731958; … ; 1.0 0.0023501801191706893 697.4948453608248; 1.0 0.0023594122268300877 703.1030927835052]
#  [0.0 0.9633142503764728 113.08; 0.78 0.1765734715158205 202.04; … ; 0.97 0.03421688505220211 508.47; 0.97 0.03422136249348078 515.36]

# %%
# effect of different scheduling rates

# %%
f = Figure(size=(FULL_WIDTH, HEIGHT), figure_padding=5)
perf_axes = f[1, 2] = GridLayout()
schedule_axes = f[1, 1] = GridLayout()
cbar_axes = f[1, 3] = GridLayout()
cmap = cgrad(:viridis, 20, scale=:log)

ax1 = Axis(perf_axes[2, 1], xlabel="#iters", ylabel="#steps"; PLOT_DEFAULTS...)
# scatter!(ax1, metrics[1:end-1, 3], [length(s) for s in tempering_schedules[1:end-1]], colormap=cmap, colorrange=[0, 1], color=metrics[1:end-1, 1], markersize=6, strokecolor=:black, strokewidth=0.5)

iters = [s[:, :iter] for s in only_last_rows_by_schedule]
idxs = [repeat([i], length(s)) for (i, s) in zip(5:21, iters[1:end-1])]
for (idx, iter, color) in zip(idxs, iters[1:end-1], cmap[metrics[1:end-1, 1]])
    boxplot!(ax1, idx, iter, orientation=:horizontal, color=color, boxcolor=:black, whiskercolor=:black, linecolor=:black, mediancolor=:black, width=0.9, strokewidth=0.5, linewidth=1, markersize=3, whiskerlinewidth=0.5, medianlinewidth=0.5, outliercolor=:black)
end

hidespines!(ax1, :r, :t)
hidedecorations!(ax1, grid=true, label=false, ticks=false, ticklabels=false)
hideydecorations!(ax1, label=true, ticks=false, ticklabels=true)


ax2 = Axis(schedule_axes[2, 1], xlabel="log κ²", ylabel="#steps", xreversed=true; PLOT_DEFAULTS...)
for (i, (c, s)) in enumerate(zip(metrics[:, 1], tempering_schedules[1:end-1]))
    lines!(ax2, log10.(s), repeat([length(s)], length(s)), color=:black, linewidth=1)
    scatter!(ax2, log10.(s), repeat([length(s)], length(s)), markersize=6, colormap=cmap, colorrange=[0, 1], color=metrics_per_κ²[i][:, 1], strokecolor=:black, strokewidth=0.5)
end

ax4 = Axis(perf_axes[1, 1]; PLOT_DEFAULTS..., yticks=[21])
hidedecorations!(ax2, grid=true, label=false, ticks=false, ticklabels=false)
hidespines!(ax4, :r, :t, :b)
rowsize!(perf_axes, 1, Relative(0.1))
rowgap!(perf_axes, 1, Relative(0.0))

ax3 = Axis(schedule_axes[1, 1], xlabel="log κ²"; PLOT_DEFAULTS..., yticks=[21])
lines!(ax3, log10.(tempering_schedules[end]), repeat([length(tempering_schedules[end])], length(tempering_schedules[end])), color=:black, linewidth=1)
scatter!(ax3, log10.(tempering_schedules[end]), repeat([length(tempering_schedules[end])], length(tempering_schedules[end])), markersize=6, colormap=cmap, marker=:x, colorrange=[0, 1], color=reverse(metrics_per_κ²[end][:, 1]), strokecolor=:black, strokewidth=0.5)

hidexdecorations!(ax3, label=true, ticks=true, ticklabels=true, grid=true)
hideydecorations!(ax3, label=true, ticks=false, ticklabels=false, grid=true)
hidespines!(ax3, :r, :t, :b)
rowsize!(schedule_axes, 1, Relative(0.05))
rowgap!(schedule_axes, 1, Relative(0.07))
hidespines!(ax2, :r, :t)

# scatter!(ax4, [metrics[end, 3]], [length(tempering_schedules[end])], colormap=cmap, colorrange=[0, 1], color=metrics[end, 1], markersize=6, marker=:x, strokecolor=:black, strokewidth=0.5)
boxplot!(ax4, repeat([21], length(iters[end])), iters[end], orientation=:horizontal, color=cmap[metrics[end, 1]], boxcolor=:black, whiskercolor=:black, linecolor=:black, mediancolor=:black, width=0.9, strokewidth=0.5, linewidth=0.5, markersize=3, whiskerlinewidth=0.5, medianlinewidth=0.5, outliercolor=:black)

hidexdecorations!(ax4, label=true, ticks=true, ticklabels=true, grid=true)
hideydecorations!(ax4, label=true, ticks=false, ticklabels=false, grid=true)
hidespines!(ax4, :r, :t, :b)
linkyaxes!(ax1, ax2)
linkxaxes!(ax1, ax4)
xlims!(ax4, 0, 1000)

rowsize!(perf_axes, 1, Relative(0.05))
rowgap!(perf_axes, 1, Relative(0.07))
colsize!(f.layout, 3, Relative(0.01))
colgap!(f.layout, 2, Relative(0.05))
colsize!(f.layout, 1, Relative(0.6))
colgap!(f.layout, 1, Relative(0.01))
Label(f.layout[1, 1, TopLeft()], "A", fontsize=10, font=:bold, padding=(0, 5, 5, 0), halign=:left)
Label(f.layout[1, 2, TopLeft()], "B", fontsize=10, font=:bold, padding=(0, 5, 5, 0), halign=:left)
cbar = Colorbar(cbar_axes[1, 1], label="conv", limits = (0, 1), colormap=cmap, ticklabelsize=7, ticksize=2, labelsize=7, width=5)

f

# %%
save(joinpath(FIGURES_PATH, "appendix_figure7.pdf"), f, overwrite=true)
# Out:
# CairoMakie.Screen{PDF}
